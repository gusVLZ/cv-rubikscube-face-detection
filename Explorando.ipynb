# %% [markdown]
# LIBRARIES

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %% [markdown]
# LOAD VIDEO AND CAPTURE A FRAME PER SEC

# %%
cap = cv.VideoCapture("video/VOD_VALORANT_SAMPLE.mp4")
fps = cap.get(cv.CAP_PROP_FPS)
sec = 0

while(cap.isOpened()):
    cap.set(cv.CAP_PROP_POS_FRAMES,sec*fps+1)
    ret, frame = cap.read()

    if ret == False:
        break

    cv.imwrite('outputs/vod1/Frame'+str(sec)+'.jpg', frame)
    sec+=1

cap.release()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\gvnv2\Desktop\P\V\Studies and Labs\Python\Explorando.ipynb Cell 5' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/gvnv2/Desktop/P/V/Studies%20and%20Labs/Python/Explorando.ipynb#ch0000006?line=4'>5</a>     if ret == False:
#       <a href='vscode-notebook-cell:/c%3A/Users/gvnv2/Desktop/P/V/Studies%20and%20Labs/Python/Explorando.ipynb#ch0000006?line=5'>6</a>         break
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gvnv2/Desktop/P/V/Studies%20and%20Labs/Python/Explorando.ipynb#ch0000006?line=7'>8</a>     cv2.imwrite('outputs/vod1/Frame'+str(sec)+'.jpg', frame)
#       <a href='vscode-notebook-cell:/c%3A/Users/gvnv2/Desktop/P/V/Studies%20and%20Labs/Python/Explorando.ipynb#ch0000006?line=8'>9</a>     sec+=1
# ...

# %% [markdown]
# LOAD IMAGE CUT AND PLAYS WITH ITS COLOR

# %%
img = cv.imread("images/PISTOL_DUASK_37S.jpg")
h = img.shape[0]
w = img.shape[1]

gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

0-1280, 0-720

kills = gray[0:int(h/3), int(w/3)*2:w]

plt.imshow(kills, cmap="Greys")

cv.imwrite("images/KILLFEED2.jpg", kills)

#_, binary = cv.threshold(kills, 160, 255, cv.THRESH_BINARY)
kills = cv.resize(kills, None, None, 4, 4)
blur = cv.medianBlur(kills, 3)
binary = cv.adaptiveThreshold(kills, 255, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, 11, 2)
plt.imshow(binary, cmap="Greys")

cv.imwrite("outputs/KF/binary.jpg",binary )
# Out:
# True
